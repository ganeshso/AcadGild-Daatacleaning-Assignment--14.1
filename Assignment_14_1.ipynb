# %% [raw]
# 2. Problem Statement
# Read the following data set:
# https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data
# Task:

# %%
import pandas as pd
import sqlite3 as sql
from sqlalchemy import create_engine

# %% [markdown]
# ## 1. Create an sqlalchemy engine using a sample from the data set

# %%
engine = create_engine('sqlite:///sqladb', echo=True)

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data',header=None)
df.head()
# Out:
#    0                  1       2           3   4                    5   \
# 0  39          State-gov   77516   Bachelors  13        Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    6               7       8        9     10  11  12  \
# 0        Adm-clerical   Not-in-family   White     Male  2174   0  40
# 1     Exec-managerial         Husband   White     Male     0   0  13
# 2   Handlers-cleaners   Not-in-family   White     Male     0   0  40
# 3   Handlers-cleaners         Husband   Black     Male     0   0  40
# 4      Prof-specialty            Wife   Black   Female     0   0  40
#
#                13      14
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
df.columns =['age','workclass','fnlwgt','education','education-num','marital-status','occupation',
           'relationship','race','sex','capital-gain','capital-loss',
           'hours-per-week','native-country','salary_slab']

# %%
df.to_sql('sqladb',engine,if_exists='replace')
# Out:
# 2018-06-13 22:51:58,783 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2018-06-13 22:51:58,798 INFO sqlalchemy.engine.base.Engine ()
# 2018-06-13 22:51:58,802 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2018-06-13 22:51:58,804 INFO sqlalchemy.engine.base.Engine ()
# 2018-06-13 22:51:58,821 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("sqladb")
# 2018-06-13 22:51:58,824 INFO sqlalchemy.engine.base.Engine ()
# 2018-06-13 22:51:58,846 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("sqladb")
# 2018-06-13 22:51:58,847 INFO sqlalchemy.engine.base.Engine ()
# 2018-06-13 22:51:58,850 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2018-06-13 22:51:58,851 INFO sqlalchemy.engine.base.Engine ()
# 2018-06-13 22:51:58,855 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("sqladb")
# ...

# %%
connection = engine.connect()

# %%
pd.read_sql_query("select * from sqladb limit 20",con=connection)
# Out:
# 2018-06-13 22:52:13,521 INFO sqlalchemy.engine.base.Engine select * from sqladb limit 20
# 2018-06-13 22:52:13,523 INFO sqlalchemy.engine.base.Engine ()
#     index  age          workclass  fnlwgt      education  education-num  \
# 0       0   39          State-gov   77516      Bachelors             13
# 1       1   50   Self-emp-not-inc   83311      Bachelors             13
# 2       2   38            Private  215646        HS-grad              9
# 3       3   53            Private  234721           11th              7
# 4       4   28            Private  338409      Bachelors             13
# 5       5   37            Private  284582        Masters             14
# 6       6   49            Private  160187            9th              5
# 7       7   52   Self-emp-not-inc  209642        HS-grad              9
# 8       8   31            Private   45781        Masters             14
# 9       9   42            Private  159449      Bachelors             13
# ...

# %% [markdown]
# # 2. Write two basic update queries

# %%
query1 = """
            update sqladb set "native-country" = "USA" 
        """
#pd.read_sql_query("""update sqladb set "native-country" = "USA" where "native-country" = "United-States" """,con=connection)
engine.execute(query1)
# Out:
# 2018-06-13 23:43:03,344 INFO sqlalchemy.engine.base.Engine
#             update sqladb set "native-country" = "USA"
# INFO:sqlalchemy.engine.base.Engine:
#             update sqladb set "native-country" = "USA"
# 2018-06-13 23:43:03,347 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
# 2018-06-13 23:43:03,809 INFO sqlalchemy.engine.base.Engine COMMIT
# INFO:sqlalchemy.engine.base.Engine:COMMIT

# %%
q = """ update sqladb set "education-num" = "education-num" + 10 """
engine.execute(q)
# Out:
# 2018-06-13 23:11:15,643 INFO sqlalchemy.engine.base.Engine  update sqladb set "education-num" = "education-num" + 10
# INFO:sqlalchemy.engine.base.Engine: update sqladb set "education-num" = "education-num" + 10
# 2018-06-13 23:11:15,647 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
# 2018-06-13 23:11:16,286 INFO sqlalchemy.engine.base.Engine COMMIT
# INFO:sqlalchemy.engine.base.Engine:COMMIT

# %%
pd.read_sql_query("select * from sqladb limit 10",con=connection)
# Out:
# 2018-06-13 23:43:12,642 INFO sqlalchemy.engine.base.Engine select * from sqladb limit 10
# INFO:sqlalchemy.engine.base.Engine:select * from sqladb limit 10
# 2018-06-13 23:43:12,645 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
#    index  age          workclass  fnlwgt   education  education-num  \
# 0      0   39          State-gov   77516   Bachelors             23
# 1      1   50   Self-emp-not-inc   83311   Bachelors             23
# 2      2   38            Private  215646     HS-grad             19
# 3      3   53            Private  234721        11th             17
# 4      4   28            Private  338409   Bachelors             23
# 5      5   37            Private  284582     Masters             24
# 6      6   49            Private  160187         9th             15
# 7      7   52   Self-emp-not-inc  209642     HS-grad             19
# 8      8   31            Private   45781     Masters             24
# ...

# %% [markdown]
# ## 3. Write two delete queries

# %%
q = """ delete from sqladb where age < 30 """
engine.execute(q)
# Out:
# 2018-06-13 23:48:52,240 INFO sqlalchemy.engine.base.Engine  delete from sqladb where age < 30
# INFO:sqlalchemy.engine.base.Engine: delete from sqladb where age < 30
# 2018-06-13 23:48:52,244 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
# 2018-06-13 23:48:52,933 INFO sqlalchemy.engine.base.Engine COMMIT
# INFO:sqlalchemy.engine.base.Engine:COMMIT

# %%
q = """ delete from sqladb where fnlwgt > 30000 """
engine.execute(q)
# Out:
# 2018-06-13 23:50:09,061 INFO sqlalchemy.engine.base.Engine  delete from sqladb where fnlwgt > 30000
# INFO:sqlalchemy.engine.base.Engine: delete from sqladb where fnlwgt > 30000
# 2018-06-13 23:50:09,065 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
# 2018-06-13 23:50:09,141 INFO sqlalchemy.engine.base.Engine COMMIT
# INFO:sqlalchemy.engine.base.Engine:COMMIT

# %%
qr = """
select * from sqladb 
"""
pd.read_sql(qr,con=connection)
# Out:
# 2018-06-13 23:50:37,705 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("
# select * from sqladb
# ")
# INFO:sqlalchemy.engine.base.Engine:PRAGMA table_info("
# select * from sqladb
# ")
# 2018-06-13 23:50:37,708 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
# 2018-06-13 23:50:37,711 INFO sqlalchemy.engine.base.Engine
# select * from sqladb
# INFO:sqlalchemy.engine.base.Engine:
# select * from sqladb
# 2018-06-13 23:50:37,714 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
#      index  age          workclass  fnlwgt      education  education-num  \
# 0       18   38            Private   28887           11th             17
# 1      184   37        Federal-gov   29054   Some-college             20
# 2      226   60                  ?   24215           10th             16
# 3      267   64            Private   21174        HS-grad             19
# 4      433   30            Private   29662     Assoc-acdm             22
# ...

# %% [markdown]
# ## 4. Write two filter queries

# %%
pd.read_sql("select * from sqladb where age > 40",con=connection)
# Out:
# 2018-06-13 23:52:24,686 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("select * from sqladb where age > 40")
# INFO:sqlalchemy.engine.base.Engine:PRAGMA table_info("select * from sqladb where age > 40")
# 2018-06-13 23:52:24,690 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
# 2018-06-13 23:52:24,693 INFO sqlalchemy.engine.base.Engine select * from sqladb where age > 40
# INFO:sqlalchemy.engine.base.Engine:select * from sqladb where age > 40
# 2018-06-13 23:52:24,696 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
#      index  age          workclass  fnlwgt      education  education-num  \
# 0      226   60                  ?   24215           10th             16
# 1      267   64            Private   21174        HS-grad             19
# 2      588   52            Private   25826           10th             16
# 3      806   50                  ?   23780        Masters             24
# ...

# %%
qr = """
    select * from sqladb where "education-num" >20
"""
pd.read_sql(qr,con=connection)
# Out:
# 2018-06-14 00:15:02,100 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("
#     select * from sqladb where ""education-num"" >20
# ")
# INFO:sqlalchemy.engine.base.Engine:PRAGMA table_info("
#     select * from sqladb where ""education-num"" >20
# ")
# 2018-06-14 00:15:02,104 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
# 2018-06-14 00:15:02,107 INFO sqlalchemy.engine.base.Engine
#     select * from sqladb where "education-num" >20
# INFO:sqlalchemy.engine.base.Engine:
#     select * from sqladb where "education-num" >20
# 2018-06-14 00:15:02,110 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
#      index  age          workclass  fnlwgt     education  education-num  \
# 0      433   30            Private   29662    Assoc-acdm             22
# 1      573   37            Private   22463     Assoc-voc             21
# 2      577   36   Self-emp-not-inc   28738    Assoc-acdm             22
# ...

# %% [markdown]
# ## 5. Write two function queries

# %%
def get10yearsOlder(age):
    return age + 10

query22 = ' select age, get10yearsOlder(age) from sqladb '
pd.read_sql(query22,con=connection)
